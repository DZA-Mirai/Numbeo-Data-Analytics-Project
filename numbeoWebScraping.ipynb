# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
import numpy as np

# %%
# URL for collecting names of the countries from the main page
url = "https://www.numbeo.com/cost-of-living/"

# URL for collecting names of cities in those countries
url_country = "https://www.numbeo.com/cost-of-living/country_result.jsp"

# URL for collecting data in collected cities
url_city = "https://www.numbeo.com/cost-of-living/in/"

# %%
page = requests.get(url)
print(page)   # <Response [200]>
# Out:
# <Response [200]>

# %%
html = BeautifulSoup(page.text, 'html')   # Parse html code

# %%
columns = html.find_all('td')[2:7]   # Getting 5 columns with country names from numbeo main page

# %%
countries = []   # List for storing countries
for column in columns:
    countries_list = column.find_all('a')   # list of countries in each column
    for country in countries_list:
        countries.append(country.text)   # Filling the list with countries

# %%
print(len(countries))   # 235 countries in 5 columns
# Out:
# 235

# %%
def column_scraping(page_html):
    table = html.find_all('table')[1]  # Getting the main table with all prices
    rows_headers = table.find_all('tr')  # Getting each row in that table
    titles = ["City", "Country", "URL", "Contributors", "Entries"]  # Titles for columns in dataframe
    for row in rows_headers:
        if row.find('td'):
            titles.append(row.find('td').text.rstrip())  # Getting title of each row
    return titles

# %%
param = {"displayCurrency": "USD", "country": countries[0]}  # Parameter for displaying all prices in USD
page_country = requests.get(url_country, params=param)
html = BeautifulSoup(page_country.text, 'html')   # Parse html code
df_titles = column_scraping(html)

# %%
# Main Dataframe for storing all the data
df = pd.DataFrame(columns=df_titles)
df
# Out:
# Empty DataFrame
# Columns: [City, Country, URL, Contributors, Entries, Meal, Inexpensive Restaurant, Meal for 2 People, Mid-range Restaurant, Three-course, McMeal at McDonalds (or Equivalent Combo Meal), Domestic Non-Alcoholic Beer (0.5 liter draught), Imported Non-Alcoholic Beer (0.33 liter bottle), Cappuccino (regular), Coke/Pepsi (0.33 liter bottle), Water (0.33 liter bottle), Milk (regular), (1 liter), Loaf of Fresh White Bread (500g), Rice (white), (1kg), Eggs (regular) (12), Local Cheese (1kg), Chicken Fillets (1kg), Beef Round (1kg) (or Equivalent Back Leg Red Meat), Apples (1kg), Banana (1kg), Oranges (1kg), Tomato (1kg), Potato (1kg), Onion (1kg), Lettuce (1 head), Water (1.5 liter bottle), Bottle of Non-Alcoholic Wine (Mid-Range), Domestic Non-Alcoholic Beer (0.5 liter bottle), Imported Non-Alcoholic Beer (0.33 liter bottle), Cigarettes 20 Pack (Marlboro), One-way Ticket (Local Transport), Monthly Pass (Regular Price), Taxi Start (Normal Tariff), Taxi 1km (Normal Tariff), Taxi 1hour Waiting (Normal Tariff), Gasoline (1 liter), Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car), Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car), Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment, Mobile Phone Monthly Plan with Calls and 10GB+ Data, Internet (60 Mbps or More, Unlimited Data, Cable/ADSL), Fitness Club, Monthly Fee for 1 Adult, Tennis Court Rent (1 Hour on Weekend), Cinema, International Release, 1 Seat, Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child, International Primary School, Yearly for 1 Child, 1 Pair of Jeans (Levis 501 Or Similar), 1 Summer Dress in a Chain Store (Zara, H&M, ...), 1 Pair of Nike Running Shoes (Mid-Range), 1 Pair of Men Leather Business Shoes, Apartment (1 bedroom) in City Centre, Apartment (1 bedroom) Outside of Centre, Apartment (3 bedrooms) in City Centre, Apartment (3 bedrooms) Outside of Centre, Price per Square Meter to Buy Apartment in City Centre, Price per Square Meter to Buy Apartment Outside of Centre, Average Monthly Net Salary (After Tax), Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate]
# Index: []
#
# [0 rows x 60 columns]

# %%
# Dataframe for exceptions during scraping
df2 = pd.DataFrame(columns=df_titles)
df2
# Out:
# Empty DataFrame
# Columns: [City, Country, URL, Contributors, Entries, Meal, Inexpensive Restaurant, Meal for 2 People, Mid-range Restaurant, Three-course, McMeal at McDonalds (or Equivalent Combo Meal), Domestic Non-Alcoholic Beer (0.5 liter draught), Imported Non-Alcoholic Beer (0.33 liter bottle), Cappuccino (regular), Coke/Pepsi (0.33 liter bottle), Water (0.33 liter bottle), Milk (regular), (1 liter), Loaf of Fresh White Bread (500g), Rice (white), (1kg), Eggs (regular) (12), Local Cheese (1kg), Chicken Fillets (1kg), Beef Round (1kg) (or Equivalent Back Leg Red Meat), Apples (1kg), Banana (1kg), Oranges (1kg), Tomato (1kg), Potato (1kg), Onion (1kg), Lettuce (1 head), Water (1.5 liter bottle), Bottle of Non-Alcoholic Wine (Mid-Range), Domestic Non-Alcoholic Beer (0.5 liter bottle), Imported Non-Alcoholic Beer (0.33 liter bottle), Cigarettes 20 Pack (Marlboro), One-way Ticket (Local Transport), Monthly Pass (Regular Price), Taxi Start (Normal Tariff), Taxi 1km (Normal Tariff), Taxi 1hour Waiting (Normal Tariff), Gasoline (1 liter), Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car), Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car), Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment, Mobile Phone Monthly Plan with Calls and 10GB+ Data, Internet (60 Mbps or More, Unlimited Data, Cable/ADSL), Fitness Club, Monthly Fee for 1 Adult, Tennis Court Rent (1 Hour on Weekend), Cinema, International Release, 1 Seat, Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child, International Primary School, Yearly for 1 Child, 1 Pair of Jeans (Levis 501 Or Similar), 1 Summer Dress in a Chain Store (Zara, H&M, ...), 1 Pair of Nike Running Shoes (Mid-Range), 1 Pair of Men Leather Business Shoes, Apartment (1 bedroom) in City Centre, Apartment (1 bedroom) Outside of Centre, Apartment (3 bedrooms) in City Centre, Apartment (3 bedrooms) Outside of Centre, Price per Square Meter to Buy Apartment in City Centre, Price per Square Meter to Buy Apartment Outside of Centre, Average Monthly Net Salary (After Tax), Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate]
# Index: []
#
# [0 rows x 60 columns]

# %%
# Function for checking conditions on how data is reliable 
# Returns True if some conditions were not satisfied
def not_reliable_data_cond_true(page_html):
    condition = page_html.find('div', class_='align_like_price_table').text
    return re.search(r'(\d+) entries', condition) is None \
        or re.search(r'(\d+) different contributors', condition) is None \
        or int(re.search(r'(\d+) different contributors', condition).group(1)) < 6 \
        or int(re.search(r'(\d+) entries', condition).group(1)) < 41

# %%
# Creating a dictionary with country names as keys and list of cities names as values
cities_dict = {}
for country in countries:
    param["country"] = country
    page_country = requests.get(url_country, params=param)
    html = BeautifulSoup(page_country.text, 'html')

    if not_reliable_data_cond_true(html):
        print('Too few data for', country)
        continue

    cities = html.find(id='city').find_all('option')
    cities_dict[country] = []
    for city in cities[1:]:
        cities_dict[country].append(city.text)   # Filling the dictionary

# %%
# The main part of the Scraping Data from numbeo
exceptions = {}    # dictionary for exceptions
cannot_find = {}   # dictionary for cities which URL are not found
param = {"displayCurrency": "USD"}


# Function that searches for the right URL and returns it
def find_city(city_link):
    global found   # flag which shows that right URL was found and the next options do not have to be checked
    page_link = requests.get(url_city + city_link, params=param)
    html = BeautifulSoup(page_link.text, 'html')
    found = 1
    # If URL was specified incorrectly numbeo can show similar cities, so I check these cities if they have the same
    # name and the same country
    if re.match(r'Cannot find city id for', html.find('h1').text.lstrip()):
        found = 0
        cities_id = html.find('div', style="error_message").find_all('a')
        j = 0
        for city_id in cities_id:
            city_country = city_id.text.rsplit(', ', maxsplit=1)
            if city == city_country[0] and country == city_country[1]:
                link = html.find('div', style="error_message").find_all('a')[j]
                link_url = link.get('href')
                page_link = requests.get(link_url, params=param)
                found = 1
                break
            j = j + 1
    return page_link


def currency_cond_true(page_html):
    currency = page_html.find('select', id="displayCurrency").find('option', selected="selected")
    if currency.text != param["displayCurrency"]:
        page_city = requests.get(page_city.url + "?displayCurrency=USD")
        page_html = BeautifulSoup(page_city.text, 'html')
    return page_html


def prices_scraping(page_html, city, country, page_city):
    table = page_html.find_all('table')[1]
    rows_prices = table.find_all('tr')
    entries = int(re.search(r'(\d+) entries', cond).group(1))
    contributors = int(re.search(r'(\d+) different contributors', cond).group(1))
    rows = [city, country, page_city.url, contributors, entries]
    for row in rows_prices:
        if row.find_all('td'):
            if row.find_all('td')[1].text.strip() == '?':
                rows.append(np.nan)
            else:
                rows.append(float(re.sub(r'[^0-9.]', '', row.find_all('td')[1].text)))
    return rows


for country in cities_dict.keys():
    for city in cities_dict[country]:
        # Different options for url that are stored in set, so there will be no duplicates
        city_country = city.replace(' ', '-').replace('(', '').replace(')', '').replace(',', '').replace('.', '') + '-' + country.replace(' ', '-')
        city_fixed = city.replace(' ', '-').replace('(', '').replace(')', '').replace(',', '').replace('.', '')
        city_state_country = re.sub(r',.+', '', city).replace(' ', '-').replace('(', '').replace(')', '').replace(',', '').replace('.', '') + '-' + country.replace(' ', '-')
        city_without_state = re.sub(r',.+', '', city).replace(' ', '-').replace('(', '').replace(')', '').replace(',', '').replace('.', '')
        city_without_bracket = re.sub(r'\(.+', '', city).rstrip()
        cities_url = {city_country, city_fixed, city_state_country, city_without_state, city_without_bracket}

        # Check each URL option in find_city() function
        found = 0
        for city_url in cities_url:
            page_city = find_city(city_url)
            html = BeautifulSoup(page_city.text, 'html')
            if found:
                break

        # If URL still cannot be found then I will just store those cities in cannot_find dictionary
        if re.match(r'Cannot find city id for', html.find('h1').text.lstrip()):
            print('Cannot find the city:', city)
            if country in cannot_find.keys():
                cannot_find[country].append(city)
            else:
                cannot_find[country] = [city]
            continue

        # Checking conditions if the data for that city was entered by more than 6 people,
        # and they made more than 41 entries
        # I created those conditions to have more reliable data
        if not_reliable_data_cond_true(html):
            print('Too few data for', city)
            continue

        # Checking if the currency in USD
        html = currency_cond_true(html)

        # Scraping all prices and converting them into float (if there is no price such entries will be filled with NaN)
        rows = prices_scraping(html, city, country, page_city)
        length = len(df)
        try:
            df.loc[length] = rows
        except Exception as e:
            logging.exception("An unexpected error happened: %s", e)
            if country in exceptions:
                exceptions[country].append(city)
            else:
                exceptions[country] = [city]
            continue

# %%
# Specific City Scraping
country = 'Ukraine'
city = 'Kiev'
page_city = requests.get('https://www.numbeo.com/cost-of-living/in/Kiev', params=param)
html = BeautifulSoup(page_city.text, 'html')
rows = prices_scraping(html, city, country, page_city)
length = len(df)
try:
    df.loc[length] = rows
except Exception as e:
    logging.exception("An unexpected error happened: %s", e)

# %%
for country in exceptions:
    for city in exceptions[country]:
        print(country, city)
# Out:
# Bangladesh Cox's Bazar
# Brunei Kuala Belait
# India Gwalior
# Indonesia Malang
# Japan Saitama
# Mauritius Grand Bay
# Spain Almeria

# %%
i = 0
for country in cannot_find:
    for city in cannot_find[country]:
        i = i + 1
        
print(i)   # 0
# Out:
# 0

# %%
df.info()   # Checking if all types are correct
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1001 entries, 0 to 1000
# Data columns (total 60 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   City                                                                        1001 non-null   object
#  1   Country                                                                     1001 non-null   object
#  2   URL                                                                         1001 non-null   object
#  3   Contributors                                                                1001 non-null   int64
#  4   Entries                                                                     1001 non-null   int64
#  5   Meal, Inexpensive Restaurant                                                994 non-null    float64
#  6   Meal for 2 People, Mid-range Restaurant, Three-course                       995 non-null    float64
#  7   McMeal at McDonalds (or Equivalent Combo Meal)                              990 non-null    float64
#  8   Domestic Non-Alcoholic Beer (0.5 liter draught)                             987 non-null    float64
#  9   Imported Non-Alcoholic Beer (0.33 liter bottle)                             991 non-null    float64
#  10  Cappuccino (regular)                                                        995 non-null    float64
#  11  Coke/Pepsi (0.33 liter bottle)                                              999 non-null    float64
#  12  Water (0.33 liter bottle)                                                   997 non-null    float64
#  13  Milk (regular), (1 liter)                                                   996 non-null    float64
#  14  Loaf of Fresh White Bread (500g)                                            997 non-null    float64
#  15  Rice (white), (1kg)                                                         992 non-null    float64
#  16  Eggs (regular) (12)                                                         999 non-null    float64
#  17  Local Cheese (1kg)                                                          986 non-null    float64
#  18  Chicken Fillets (1kg)                                                       993 non-null    float64
#  19  Beef Round (1kg) (or Equivalent Back Leg Red Meat)                          984 non-null    float64
#  20  Apples (1kg)                                                                992 non-null    float64
#  21  Banana (1kg)                                                                997 non-null    float64
#  22  Oranges (1kg)                                                               984 non-null    float64
#  23  Tomato (1kg)                                                                985 non-null    float64
#  24  Potato (1kg)                                                                987 non-null    float64
#  25  Onion (1kg)                                                                 987 non-null    float64
#  26  Lettuce (1 head)                                                            976 non-null    float64
#  27  Water (1.5 liter bottle)                                                    990 non-null    float64
#  28  Bottle of Non-Alcoholic Wine (Mid-Range)                                    985 non-null    float64
#  29  Domestic Non-Alcoholic Beer (0.5 liter bottle)                              976 non-null    float64
#  30  Imported Non-Alcoholic Beer (0.33 liter bottle)                             972 non-null    float64
#  31  Cigarettes 20 Pack (Marlboro)                                               981 non-null    float64
#  32  One-way Ticket (Local Transport)                                            983 non-null    float64
#  33  Monthly Pass (Regular Price)                                                911 non-null    float64
#  34  Taxi Start (Normal Tariff)                                                  947 non-null    float64
#  35  Taxi 1km (Normal Tariff)                                                    906 non-null    float64
#  36  Taxi 1hour Waiting (Normal Tariff)                                          867 non-null    float64
#  37  Gasoline (1 liter)                                                          995 non-null    float64
#  38  Volkswagen Golf 1.4 90 KW Trendline (Or Equivalent New Car)                 942 non-null    float64
#  39  Toyota Corolla Sedan 1.6l 97kW Comfort (Or Equivalent New Car)              945 non-null    float64
#  40  Basic (Electricity, Heating, Cooling, Water, Garbage) for 85m2 Apartment    990 non-null    float64
#  41  Mobile Phone Monthly Plan with Calls and 10GB+ Data                         982 non-null    float64
#  42  Internet (60 Mbps or More, Unlimited Data, Cable/ADSL)                      991 non-null    float64
#  43  Fitness Club, Monthly Fee for 1 Adult                                       989 non-null    float64
#  44  Tennis Court Rent (1 Hour on Weekend)                                       911 non-null    float64
#  45  Cinema, International Release, 1 Seat                                       982 non-null    float64
#  46  Preschool (or Kindergarten), Full Day, Private, Monthly for 1 Child         951 non-null    float64
#  47  International Primary School, Yearly for 1 Child                            859 non-null    float64
#  48  1 Pair of Jeans (Levis 501 Or Similar)                                      979 non-null    float64
#  49  1 Summer Dress in a Chain Store (Zara, H&M, ...)                            962 non-null    float64
#  50  1 Pair of Nike Running Shoes (Mid-Range)                                    984 non-null    float64
#  51  1 Pair of Men Leather Business Shoes                                        967 non-null    float64
#  52  Apartment (1 bedroom) in City Centre                                        988 non-null    float64
#  53  Apartment (1 bedroom) Outside of Centre                                     988 non-null    float64
#  54  Apartment (3 bedrooms) in City Centre                                       991 non-null    float64
#  55  Apartment (3 bedrooms) Outside of Centre                                    989 non-null    float64
#  56  Price per Square Meter to Buy Apartment in City Centre                      934 non-null    float64
#  57  Price per Square Meter to Buy Apartment Outside of Centre                   931 non-null    float64
#  58  Average Monthly Net Salary (After Tax)                                      992 non-null    float64
#  59  Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate  973 non-null    float64
# dtypes: float64(55), int64(2), object(3)
# memory usage: 477.0+ KB

# %%
df2
# Out:
#            City     Country  \
# 0   Cox's Bazar  Bangladesh
# 1  Kuala Belait      Brunei
# 2       Gwalior       India
# 3        Malang   Indonesia
# 4       Saitama       Japan
# 5     Grand Bay   Mauritius
# 6       Almeria       Spain
#
#                                                  URL  Contributors  Entries  \
# 0  https://www.numbeo.com/cost-of-living/in/Cox's...             6       79
# 1  https://www.numbeo.com/cost-of-living/in/Kuala...             6       50
# 2  https://www.numbeo.com/cost-of-living/in/Gwali...             9      203
# 3  https://www.numbeo.com/cost-of-living/in/Malan...             9       92
# 4  https://www.numbeo.com/cost-of-living/in/Saita...             7       47
# 5  https://www.numbeo.com/cost-of-living/in/Grand...            10      110
# 6  https://www.numbeo.com/cost-of-living/in/Almer...            15      138
#
#    Meal, Inexpensive Restaurant  \
# 0                          1.82
# 1                          7.50
# 2                          1.81
# 3                          1.38
# 4                          9.63
# 5                          9.81
# 6                         15.18
#
#    Meal for 2 People, Mid-range Restaurant, Three-course  \
# 0                                              20.50
# 1                                              45.00
# 2                                              18.10
# 3                                               7.70
# 4                                              28.73
# 5                                              50.12
# 6                                              54.70
#
#    McMeal at McDonalds (or Equivalent Combo Meal)  \
# 0                                            3.42
# 1                                            7.24
# 2                                            3.62
# 3                                            3.21
# 4                                            4.23
# 5                                            4.63
# 6                                            8.75
#
#    Domestic Non-Alcoholic Beer (0.5 liter draught)  \
# 0                                             9.11
# 1                                             2.81
# 2                                             1.87
# 3                                             2.89
# 4                                             5.07
# 5                                             3.27
# 6                                             3.56
#
#    Imported Non-Alcoholic Beer (0.33 liter bottle)  ...  \
# 0                                             2.73  ...
# 1                                             2.25  ...
# 2                                             3.02  ...
# 3                                             4.65  ...
# 4                                             3.38  ...
# 5                                             5.45  ...
# 6                                             3.83  ...
#
#    1 Pair of Nike Running Shoes (Mid-Range)  \
# 0                                     36.45
# 1                                    118.03
# 2                                     49.77
# 3                                     54.54
# 4                                     52.39
# 5                                    116.22
# 6                                     83.42
#
#    1 Pair of Men Leather Business Shoes  Apartment (1 bedroom) in City Centre  \
# 0                                 91.13                                182.27
# 1                                132.62                                637.47
# 2                                 49.77                                120.65
# 3                                 77.00                                170.04
# 4                                101.41                                405.62
# 5                                 83.53                                617.42
# 6                                114.87                                437.59
#
#    Apartment (1 bedroom) Outside of Centre  \
# 0                                   109.36
# 1                                   599.97
# 2                                    80.43
# 3                                    48.12
# 4                                   236.61
# 5                                   363.19
# 6                                   337.31
#
#    Apartment (3 bedrooms) in City Centre  \
# 0                                 341.75
# 1                                1050.64
# 2                                 217.17
# 3                                 288.74
# 4                                1216.87
# 5                                 958.81
# 6                                 867.88
#
#    Apartment (3 bedrooms) Outside of Centre  \
# 0                                    182.27
# 1                                    900.79
# 2                                    144.78
# 3                                     96.25
# 4                                    980.26
# 5                                   1198.52
# 6                                    667.32
#
#    Price per Square Meter to Buy Apartment in City Centre  \
# 0                                             515.00
# 1                                                NaN
# 2                                             670.81
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#    Price per Square Meter to Buy Apartment Outside of Centre  \
# 0                                             367.86
# 1                                                NaN
# 2                                             373.46
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                            1312.77
#
#    Average Monthly Net Salary (After Tax)  \
# 0                                  318.97
# 1                                 2037.61
# 2                                  482.59
# 3                                  273.77
# 4                                 1780.24
# 5                                  980.61
# 6                                 1238.92
#
#    Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 0                                                NaN
# 1                                                NaN
# 2                                               9.62
# 3                                               4.00
# 4                                               1.86
# 5                                               6.50
# 6                                               3.50
#
# [7 rows x 60 columns]

# %%
combined_df = pd.concat([df, df2])
combined_df.reset_index(drop=True, inplace=True)
combined_df.index = range(1, len(combined_df)+1)
combined_df
# Out:
#            City      Country  \
# 1         Kabul  Afghanistan
# 2        Tirana      Albania
# 3         Vlore      Albania
# 4       Algiers      Algeria
# 5        Annaba      Algeria
# ...         ...          ...
# 1004    Gwalior        India
# 1005     Malang    Indonesia
# 1006    Saitama        Japan
# 1007  Grand Bay    Mauritius
# 1008    Almeria        Spain
#
#                                                     URL  Contributors  \
# 1     https://www.numbeo.com/cost-of-living/in/Kabul...            14
# 2     https://www.numbeo.com/cost-of-living/in/Tiran...           145
# 3     https://www.numbeo.com/cost-of-living/in/Vlore...            25
# 4     https://www.numbeo.com/cost-of-living/in/Algie...           127
# 5     https://www.numbeo.com/cost-of-living/in/Annab...            10
# ...                                                 ...           ...
# 1004  https://www.numbeo.com/cost-of-living/in/Gwali...             9
# 1005  https://www.numbeo.com/cost-of-living/in/Malan...             9
# 1006  https://www.numbeo.com/cost-of-living/in/Saita...             7
# 1007  https://www.numbeo.com/cost-of-living/in/Grand...            10
# 1008  https://www.numbeo.com/cost-of-living/in/Almer...            15
#
#       Entries  Meal, Inexpensive Restaurant  \
# 1         149                          2.12
# 2        1867                         10.56
# 3         285                          8.44
# 4        1485                          2.98
# 5         134                          2.98
# ...       ...                           ...
# 1004      203                          1.81
# 1005       92                          1.38
# 1006       47                          9.63
# 1007      110                          9.81
# 1008      138                         15.18
#
#       Meal for 2 People, Mid-range Restaurant, Three-course  \
# 1                                                 11.30
# 2                                                 52.78
# 3                                                 31.67
# 4                                                 22.33
# 5                                                 22.33
# ...                                                 ...
# 1004                                              18.10
# 1005                                               7.70
# 1006                                              28.73
# 1007                                              50.12
# 1008                                              54.70
#
#       McMeal at McDonalds (or Equivalent Combo Meal)  \
# 1                                               5.30
# 2                                               7.92
# 3                                               6.33
# 4                                               4.47
# 5                                               4.47
# ...                                              ...
# 1004                                            3.62
# 1005                                            3.21
# 1006                                            4.23
# 1007                                            4.63
# 1008                                            8.75
#
#       Domestic Non-Alcoholic Beer (0.5 liter draught)  \
# 1                                                4.94
# 2                                                2.64
# 3                                                3.17
# 4                                                1.86
# 5                                                0.89
# ...                                               ...
# 1004                                             1.87
# 1005                                             2.89
# 1006                                             5.07
# 1007                                             3.27
# 1008                                             3.56
#
#       Imported Non-Alcoholic Beer (0.33 liter bottle)  ...  \
# 1                                                1.69  ...
# 2                                                3.69  ...
# 3                                                3.43  ...
# 4                                                2.42  ...
# 5                                                1.49  ...
# ...                                               ...  ...
# 1004                                             3.02  ...
# 1005                                             4.65  ...
# 1006                                             3.38  ...
# 1007                                             5.45  ...
# 1008                                             3.83  ...
#
#       1 Pair of Nike Running Shoes (Mid-Range)  \
# 1                                        44.73
# 2                                        92.78
# 3                                        65.97
# 4                                        78.16
# 5                                        83.87
# ...                                        ...
# 1004                                     49.77
# 1005                                     54.54
# 1006                                     52.39
# 1007                                    116.22
# 1008                                     83.42
#
#       1 Pair of Men Leather Business Shoes  \
# 1                                    32.49
# 2                                   123.28
# 3                                    52.78
# 4                                    75.18
# 5                                    81.88
# ...                                    ...
# 1004                                 49.77
# 1005                                 77.00
# 1006                                101.41
# 1007                                 83.53
# 1008                                114.87
#
#       Apartment (1 bedroom) in City Centre  \
# 1                                   139.23
# 2                                   545.12
# 3                                   330.77
# 4                                   237.19
# 5                                   200.99
# ...                                    ...
# 1004                                120.65
# 1005                                170.04
# 1006                                405.62
# 1007                                617.42
# 1008                                437.59
#
#       Apartment (1 bedroom) Outside of Centre  \
# 1                                       95.34
# 2                                      369.81
# 3                                      233.32
# 4                                      144.85
# 5                                      129.03
# ...                                       ...
# 1004                                    80.43
# 1005                                    48.12
# 1006                                   236.61
# 1007                                   363.19
# 1008                                   337.31
#
#       Apartment (3 bedrooms) in City Centre  \
# 1                                    261.31
# 2                                   1063.95
# 3                                    493.03
# 4                                    395.88
# 5                                    310.16
# ...                                     ...
# 1004                                 217.17
# 1005                                 288.74
# 1006                                1216.87
# 1007                                 958.81
# 1008                                 867.88
#
#       Apartment (3 bedrooms) Outside of Centre  \
# 1                                       171.26
# 2                                       629.26
# 3                                       381.04
# 4                                       254.45
# 5                                       210.91
# ...                                        ...
# 1004                                    144.78
# 1005                                     96.25
# 1006                                    980.26
# 1007                                   1198.52
# 1008                                    667.32
#
#       Price per Square Meter to Buy Apartment in City Centre  \
# 1                                                434.54
# 2                                               2761.26
# 3                                               1166.78
# 4                                               1995.27
# 5                                                953.45
# ...                                                 ...
# 1004                                             670.81
# 1005                                                NaN
# 1006                                                NaN
# 1007                                                NaN
# 1008                                                NaN
#
#       Price per Square Meter to Buy Apartment Outside of Centre  \
# 1                                                264.84
# 2                                               1419.56
# 3                                                791.44
# 4                                               1121.93
# 5                                                545.92
# ...                                                 ...
# 1004                                             373.46
# 1005                                                NaN
# 1006                                                NaN
# 1007                                                NaN
# 1008                                            1312.77
#
#       Average Monthly Net Salary (After Tax)  \
# 1                                     181.86
# 2                                     650.47
# 3                                     420.38
# 4                                     319.30
# 5                                     282.87
# ...                                      ...
# 1004                                  482.59
# 1005                                  273.77
# 1006                                 1780.24
# 1007                                  980.61
# 1008                                 1238.92
#
#       Mortgage Interest Rate in Percentages (%), Yearly, for 20 Years Fixed-Rate
# 1                                                 14.25
# 2                                                  5.47
# 3                                                  4.00
# 4                                                  6.49
# 5                                                  5.75
# ...                                                 ...
# 1004                                               9.62
# 1005                                               4.00
# 1006                                               1.86
# 1007                                               6.50
# 1008                                               3.50
#
# [1008 rows x 60 columns]

# %%
combined_df.to_csv(r'C:\Users\User\OneDrive\Documents\Python Web Scraping\numbeo_cities.csv')

# %%
# Decided to add three more columns with population, latitude and longitude
# Downloaded different datasets and used APIs with city names and coordinates and tried to concatenate them with my DataFrame
# Then, found out that there is very helpful library Geopy for finding coordinates of locations and used it for left cities

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --------- ------------------------------ 30.7/125.4 kB 1.4 MB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.9 MB/s eta 0:00:00
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB ? eta 0:00:00
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.4.1

# %%
from geopy.geocoders import Nominatim

cannot_find = {}
df_new_columns = pd.DataFrame(columns=['lat', 'lng'])

for index, row in df_result[['City', 'Country']].iterrows():
    geolocator = Nominatim(user_agent="myapp")
    location = geolocator.geocode(row[0] + ', ' + row[1])
    try:
        print(location.latitude, location.longitude)
        df_new_columns.loc[index, ['lat', 'lng']] = [location.latitude, location.longitude]
    except Exception as e:
        df_new_columns.loc[index, ['lat', 'lng']] = [np.NaN, np.NaN]
        logging.exception("Location was not found: %s", e)
        if row[1] in cannot_find.keys():
            cannot_find[row[1]].append(row[0])
        else:
            cannot_find[row[1]] = [row[0]]
        continue

# %%
print(cannot_find)
# Out:
# {'Tunisia': ['Aryanah (Ariana)']}

# %%
city_country_df = df_result[df_result['lat'].isna()][['City', 'Country']]
print(city_country_df)

# %%
df_result = pd.concat([combined_df, df_new_columns], axis=1)
df_result.to_csv(r'C:\Users\User\OneDrive\Documents\Python Web Scraping\numbeo_cities_updated.csv')
